# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## IMPORTING DATA

# %%
file_path = r"C:\Users\dell\Documents\AMES DATA\Ames_Housing_Data.csv" ##please copy your dataset's path after r using copy as path
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %% [markdown]
# ## CLEANING DATA

# %%
df.corr(numeric_only = True)['SalePrice'].sort_values()
# Out:
# PID               -0.246521
# Enclosed Porch    -0.128787
# Kitchen AbvGr     -0.119814
# Overall Cond      -0.101697
# MS SubClass       -0.085092
# Low Qual Fin SF   -0.037660
# Bsmt Half Bath    -0.035835
# Yr Sold           -0.030569
# Misc Val          -0.015691
# BsmtFin SF 2       0.005891
# 3Ssn Porch         0.032225
# Mo Sold            0.035259
# Pool Area          0.068403
# Screen Porch       0.112151
# Bedroom AbvGr      0.143913
# Bsmt Unf SF        0.182855
# Lot Area           0.266549
# 2nd Flr SF         0.269373
# Bsmt Full Bath     0.276050
# Half Bath          0.285056
# Open Porch SF      0.312951
# Wood Deck SF       0.327143
# Lot Frontage       0.357318
# BsmtFin SF 1       0.432914
# Fireplaces         0.474558
# TotRms AbvGrd      0.495474
# Mas Vnr Area       0.508285
# Garage Yr Blt      0.526965
# Year Remod/Add     0.532974
# Full Bath          0.545604
# Year Built         0.558426
# 1st Flr SF         0.621676
# Total Bsmt SF      0.632280
# ...

# %%
sns.scatterplot(x = 'Overall Qual', y = 'SalePrice', data = df)
# Out:
# <Axes: xlabel='Overall Qual', ylabel='SalePrice'>

# %%
sns.scatterplot(x = 'Gr Liv Area', y = 'SalePrice', data = df)
# Out:
# <Axes: xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
df[(df['Overall Qual']>8) & (df['SalePrice']<200000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1182  533350090           60        RL           NaN     24572   Pave   NaN
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1182       IR1          Lvl    AllPub  ...         0     NaN   NaN
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1182          NaN        0       6    2008        WD           Family
# 1498          NaN        0       1    2008        New         Partial
# ...

# %%
df[(df['SalePrice'] < 210000)& (df['Gr Liv Area']>4000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1498          NaN        0       1    2008        New         Partial
# 2180         Elev    17000      10    2007        New         Partial
# 2181          NaN        0      10    2007        New         Partial
#
#       SalePrice
# 1498     160000
# 2180     183850
# 2181     184750
#
# [3 rows x 81 columns]

# %% [markdown]
# ### REMOVING OUTLIERS

# %%
drop_ind = df[(df['SalePrice'] < 210000)& (df['Gr Liv Area']>4000)]

# %%
df = df.drop(drop_ind.index , axis = 0)

# %%
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %% [markdown]
# ### DEALING WITH MISSING DATA

# %%
df.isnull().sum()
# Out:
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
# Lot Area            0
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 81, dtype: int64

# %%
100 * df.isnull().sum()/len(df)
# Out:
# PID                0.00000
# MS SubClass        0.00000
# MS Zoning          0.00000
# Lot Frontage      16.74069
# Lot Area           0.00000
#                     ...
# Mo Sold            0.00000
# Yr Sold            0.00000
# Sale Type          0.00000
# Sale Condition     0.00000
# SalePrice          0.00000
# Length: 81, dtype: float64

# %%
#Creating a function to find out how many missing values per feature
def percent_missing(df):
    percent_nan = 100 * df.isnull().sum()/len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values()

    return percent_nan

# %%
percent_nan = percent_missing(df)

# %%
percent_nan
# Out:
# Electrical         0.034165
# Garage Cars        0.034165
# BsmtFin SF 1       0.034165
# Garage Area        0.034165
# BsmtFin SF 2       0.034165
# Bsmt Unf SF        0.034165
# Total Bsmt SF      0.034165
# Bsmt Half Bath     0.068329
# Bsmt Full Bath     0.068329
# Mas Vnr Area       0.785787
# Bsmt Qual          2.733174
# Bsmt Cond          2.733174
# BsmtFin Type 1     2.733174
# BsmtFin Type 2     2.767339
# Bsmt Exposure      2.835668
# Garage Type        5.363854
# Garage Qual        5.432183
# Garage Cond        5.432183
# Garage Yr Blt      5.432183
# Garage Finish      5.432183
# Lot Frontage      16.740690
# Fireplace Qu      48.582166
# Mas Vnr Type      60.642296
# Fence             80.457807
# Alley             93.235395
# Misc Feature      96.412709
# Pool QC           99.590024
# dtype: float64

# %% [markdown]
# ### CHARTING MISSING DATA

# %%
sns.barplot(x = percent_nan.index, y = percent_nan)
plt.xticks(rotation = 90)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
percent_nan[percent_nan < 1]
#Features that are missing less than 1 percent of their data
# Out:
# Electrical        0.034165
# Garage Cars       0.034165
# BsmtFin SF 1      0.034165
# Garage Area       0.034165
# BsmtFin SF 2      0.034165
# Bsmt Unf SF       0.034165
# Total Bsmt SF     0.034165
# Bsmt Half Bath    0.068329
# Bsmt Full Bath    0.068329
# Mas Vnr Area      0.785787
# dtype: float64

# %%
df[df['Electrical'].isnull()]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1577  916386080           80        RL          73.0      9735   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1577       Reg          Lvl    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1577          NaN        0       5    2008        WD           Normal
#
#       SalePrice
# 1577     167500
#
# [1 rows x 81 columns]

# %%
df[df['Bsmt Half Bath'].isnull()]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1341  903230120           20        RM          99.0      5940   Pave   NaN
# 1497  908154080           20        RL         123.0     47007   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 1341       IR1          Lvl    AllPub  ...         0     NaN  MnPrv
# 1497       IR1          Lvl    AllPub  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4    2008      ConLD         Abnorml
# 1497          NaN        0       7    2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 81 columns]

# %% [markdown]
# ### Dropping rows in case of features with minimal missing values (less than 1 percent)

# %%
df = df.dropna(axis = 0, subset = ['Electrical','Garage Cars'])

# %%
percent_nan = percent_missing(df)

# %%
percent_nan[percent_nan < 1]
# Out:
# Bsmt Unf SF       0.034188
# Total Bsmt SF     0.034188
# BsmtFin SF 2      0.034188
# BsmtFin SF 1      0.034188
# Bsmt Full Bath    0.068376
# Bsmt Half Bath    0.068376
# Mas Vnr Area      0.786325
# dtype: float64

# %% [markdown]
# ### Filling values for NaN in case of features considerable amount of data missing

# %%
bsmt_num_cols = ['BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF','Total Bsmt SF','Bsmt Full Bath','Bsmt Half Bath']
df.loc[:, bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

# %%
bsmt_str_cols = ['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']
df.loc[:, bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# %%
percent_nan = percent_missing(df)

# %%
percent_nan[percent_nan < 1]
# Out:
# Mas Vnr Area    0.786325
# dtype: float64

# %%
df.loc[:,'Mas Vnr Type'] = df['Mas Vnr Type'].fillna('None')
df.loc[:,'Mas Vnr Area'] = df['Mas Vnr Area'].fillna(0)

# %%
sns.barplot(x = percent_nan.index, y = percent_nan)
plt.xticks(rotation = 90)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
gar_str_cols = ['Garage Type','Garage Finish', 'Garage Qual','Garage Cond']
df.loc[:,gar_str_cols] = df[gar_str_cols].fillna('None')

# %%
percent_nan = percent_missing(df)

# %% [markdown]
# ### VISUALIZING & TREATING FEATURES WITH MORE THAN 1 PERCENT DATA MISSING

# %%
plt.figure(figsize = (8,4), dpi = 200)
sns.barplot(x = percent_nan.index, y = percent_nan)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Garage Yr Blt'),
#   Text(1, 0, 'Lot Frontage'),
#   Text(2, 0, 'Fireplace Qu'),
#   Text(3, 0, 'Fence'),
#   Text(4, 0, 'Alley'),
#   Text(5, 0, 'Misc Feature'),
#   Text(6, 0, 'Pool QC')])

# %%
df.loc[:,'Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)
df = df.drop(['Pool QC', 'Misc Feature','Alley','Fence'],axis = 1)

# %%
percent_nan = percent_missing(df)

plt.figure(figsize = (8,4),dpi = 200)
sns.barplot(x = percent_nan.index, y = percent_nan)
plt.xticks(rotation = 90)
# Out:
# ([0, 1], [Text(0, 0, 'Lot Frontage'), Text(1, 0, 'Fireplace Qu')])

# %%
df['Fireplace Qu'] = df['Fireplace Qu'].fillna('None')
plt.figure(figsize = (8,12),dpi = 200)
sns.boxplot(x = 'Lot Frontage', y = 'Neighborhood', data = df, orient = 'h')
# Out:
# <Axes: xlabel='Lot Frontage', ylabel='Neighborhood'>

# %%
df.groupby('Neighborhood')['Lot Frontage'].mean()
# Out:
# Neighborhood
# Blmngtn    46.900000
# Blueste    27.300000
# BrDale     21.500000
# BrkSide    55.789474
# ClearCr    88.150000
# CollgCr    71.336364
# Crawfor    69.951807
# Edwards    64.794286
# Gilbert    74.207207
# Greens     41.000000
# GrnHill          NaN
# IDOTRR     62.383721
# Landmrk          NaN
# MeadowV    25.606061
# Mitchel    75.144444
# NAmes      75.210667
# NPkVill    28.142857
# NWAmes     81.517647
# NoRidge    91.629630
# NridgHt    84.184049
# OldTown    61.777293
# SWISU      59.068182
# Sawyer     74.551020
# SawyerW    70.669811
# Somerst    64.549383
# StoneBr    62.173913
# Timber     81.303571
# Veenker    72.000000
# Name: Lot Frontage, dtype: float64

# %% [markdown]
# ### Filling Missing value for lot frontage with average lot frontage value for that neighborhood

# %%
df['Lot Frontage'] = df.groupby('Neighborhood')['Lot Frontage'].transform(lambda x: x.fillna(x.mean()))

# %%
df.isnull().sum()
# Out:
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      3
# Lot Area          0
# Street            0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 76, dtype: int64

# %%
df['Lot Frontage'] = df['Lot Frontage'].fillna(0)

# %%
df.isnull().sum()
# Out:
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
# Lot Area          0
# Street            0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 76, dtype: int64

# %%
percent_nan = percent_missing(df)

plt.figure(figsize = (8,4),dpi = 200)
sns.barplot(x = percent_nan.index, y = percent_nan)
plt.xticks(rotation = 90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %% [markdown]
# # DATA WITH NO VARIABLE

# %%
df.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0           20        RL         141.0     31770   Pave       IR1
# 1           20        RH          80.0     11622   Pave       Reg
# 2           20        RL          81.0     14267   Pave       IR1
# 3           20        RL          93.0     11160   Pave       Reg
# 4           60        RL          74.0     13830   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch 3Ssn Porch  \
# 0          Lvl    AllPub     Corner        Gtl  ...              0          0
# 1          Lvl    AllPub     Inside        Gtl  ...              0          0
# 2          Lvl    AllPub     Corner        Gtl  ...              0          0
# 3          Lvl    AllPub     Corner        Gtl  ...              0          0
# 4          Lvl    AllPub     Inside        Gtl  ...              0          0
#
#   Screen Porch Pool Area Misc Val  Mo Sold  Yr Sold  Sale Type  \
# ...

# %%
df
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0              20        RL    141.000000     31770   Pave       IR1
# 1              20        RH     80.000000     11622   Pave       Reg
# 2              20        RL     81.000000     14267   Pave       IR1
# 3              20        RL     93.000000     11160   Pave       Reg
# 4              60        RL     74.000000     13830   Pave       IR1
# ...           ...       ...           ...       ...    ...       ...
# 2925           80        RL     37.000000      7937   Pave       IR1
# 2926           20        RL     75.144444      8885   Pave       IR1
# 2927           85        RL     62.000000     10441   Pave       Reg
# 2928           20        RL     77.000000     10010   Pave       Reg
# 2929           60        RL     74.000000      9627   Pave       Reg
#
#      Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch  \
# ...

# %% [markdown]
# ## GETTING DUMMY VARIABLES FOR STRINGS/OBJECTS

# %%
with open("C:/Users/dell/Documents/AMES DATA/Ames_Housing_Feature_Description.txt") as f:
    print(f.read())
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
df['MS SubClass'] = df['MS SubClass'].apply(str)

# %%
#The dataframe with no missing values and no outliers is finally used to get dummies for strings/objects by splitting it into two dataframes one for objects and the other for numeric features
my_object_df = df.select_dtypes(include = 'object')

# %%
my_numeric_df = df.select_dtypes(exclude = 'object')

# %%
my_numeric_df
# Out:
#       Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year Built  \
# 0       141.000000     31770             6             5        1960
# 1        80.000000     11622             5             6        1961
# 2        81.000000     14267             6             6        1958
# 3        93.000000     11160             7             5        1968
# 4        74.000000     13830             5             5        1997
# ...            ...       ...           ...           ...         ...
# 2925     37.000000      7937             6             6        1984
# 2926     75.144444      8885             5             5        1983
# 2927     62.000000     10441             5             5        1992
# 2928     77.000000     10010             5             5        1974
# 2929     74.000000      9627             7             5        1993
#
#       Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
my_object_df
# Out:
#      MS SubClass MS Zoning Street Lot Shape Land Contour Utilities Lot Config  \
# 0             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 1             20        RH   Pave       Reg          Lvl    AllPub     Inside
# 2             20        RL   Pave       IR1          Lvl    AllPub     Corner
# 3             20        RL   Pave       Reg          Lvl    AllPub     Corner
# 4             60        RL   Pave       IR1          Lvl    AllPub     Inside
# ...          ...       ...    ...       ...          ...       ...        ...
# 2925          80        RL   Pave       IR1          Lvl    AllPub    CulDSac
# 2926          20        RL   Pave       IR1          Low    AllPub     Inside
# 2927          85        RL   Pave       Reg          Lvl    AllPub     Inside
# 2928          20        RL   Pave       Reg          Lvl    AllPub     Inside
# 2929          60        RL   Pave       Reg          Lvl    AllPub     Inside
#
# ...

# %%
df_objects_dummies = pd.get_dummies(my_object_df, drop_first = True)

# %%
df_objects_dummies
# Out:
#       MS SubClass_150  MS SubClass_160  MS SubClass_180  MS SubClass_190  \
# 0               False            False            False            False
# 1               False            False            False            False
# 2               False            False            False            False
# 3               False            False            False            False
# 4               False            False            False            False
# ...               ...              ...              ...              ...
# 2925            False            False            False            False
# 2926            False            False            False            False
# 2927            False            False            False            False
# 2928            False            False            False            False
# 2929            False            False            False            False
#
#       MS SubClass_20  MS SubClass_30  MS SubClass_40  MS SubClass_45  \
# ...

# %% [markdown]
# ## GETTING FINAL DATAFRAME BY CONCATENATING DUMMY VARIABLE AND NUMERIC DATAFRAMES

# %%
final_df = pd.concat([my_numeric_df,df_objects_dummies],axis = 1)

# %%
final_df.to_csv('Ames Final Data', index=False) #EXPORTING FINAL DATAFRAME SO IT CAN BE READ AGAIN IN CASE OF ACCIDENTAL, UNWANTED ALTERATIONS

# %%
df = final_df

# %% [markdown]
# # LINEAR REGRESSION PART

# %%
X = df.drop('SalePrice', axis = 1)
y = df['SalePrice']

# %% [markdown]
# ### CREATING THE TRAIN TEST SPLIT OF AVAILABLE DATA

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.1, random_state = 101)

#Test set kept small because we are going to perform cross-validation

# %% [markdown]
# ### Scaling data to ensure all features contribute fairly

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test) #NOTE: NO FITTING TO TEST DATA TO PREVENT DATA LEAKAGE

# %% [markdown]
# ### SETTING UP THE ELASTIC NET MODEL

# %%
from sklearn.linear_model import ElasticNet

# %%
base_elastic_net = ElasticNet(max_iter = 1000000)

# %%
#SETTING UP THE GRID FOR GRID SEARCH
param_grid = {'alpha':[0.1,1,5,10,100], 'l1_ratio':[0.1, 0.7, 0.99,1]}

# %% [markdown]
# ### SETTING UP THE GRID SEARCH ALGORITHM TO TUNE THE HYPERPARAMETERS

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(base_elastic_net, param_grid = param_grid, scoring = 'neg_mean_squared_error', cv = 5, verbose = 1)

# %% [markdown]
# ### FITTING MODEL ONTO THE TRAINING DATA

# %%
grid_model.fit(scaled_X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.542e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.635e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
#getting best params for the elastic net model
grid_model.best_params_
# Out:
# {'alpha': 100, 'l1_ratio': 1}

# %% [markdown]
# ## EVALUATING THE MODEL PERFORMANCE ON THE TEST SET OF 10 PERCENT SCALED TEST SET

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=100, l1_ratio=1)

# %%
y_pred = grid_model.predict(scaled_X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 14195.354900562172

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 20558.508566893175

# %%
np.mean(df['SalePrice'])
# Out:
# 180815.53743589742

# %% [markdown]
# ### EXPORTING THE FINAL MODEL FOR FUTURE USE

# %%
import joblib

# %%
# EXPORTING SCALER AND FINAL MODEL

# %%
joblib.dump(scaler, 'scaler.joblib')
# Out:
# ['scaler.joblib']

# %%
final_model = grid_model.best_estimator_
joblib.dump(final_model, 'final_model.joblib')
# Out:
# ['final_model.joblib']
